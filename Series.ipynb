# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.8 MB 13.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.8 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.8 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 13.2 MB/s  0:00:00
# ...

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([101,201,301])
dic={1:110,2:220,3:330}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    101
# b    201
# c    301
# dtype: int64

# %%
pd.Series(dic)
# Out:
# 1    110
# 2    220
# 3    330
# dtype: int64
