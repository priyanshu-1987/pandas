# %%
import numpy as np
import pandas as pd

# %%
data={
    'category':['A','B','A','B','A','B','A','B'],
    'store':['S1','S1','S2','S2','S1','S2','S2','S1'],
    'sales':[100,200,150,250,120,100,200,300],
    'Quantity':[10,15,12,18,8,20,15,25],
    'Date':pd.date_range('2023-01-01',periods=8)
}
df=pd.DataFrame(data)

# %%
df
# Out:
#   category store  sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    100        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#group by category and calculate the sum of sales
c=df.groupby('category')
for i ,v in c:
    print(i)
    print(v)
# Out:
# A
#   category store  sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   category store  sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    100        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
c['sales'].sum()
# Out:
# category
# A    570
# B    850
# Name: sales, dtype: int64

# %%
d=df.groupby('store')['sales'].sum()

# %%
d
# Out:
# store
# S1    720
# S2    700
# Name: sales, dtype: int64

# %%
e=df.groupby(['store','category'])['sales'].sum()

# %%
e
# Out:
# store  category
# S1     A           220
#        B           500
# S2     A           350
#        B           350
# Name: sales, dtype: int64

# %% [markdown]
# Aggregation

# %%
df['sales'].mean()
# Out:
# np.float64(177.5)

# %%
df['sales'].median()
# Out:
# np.float64(175.0)

# %%
df['sales'].mode()
# Out:
# 0    100
# 1    200
# Name: sales, dtype: int64

# %%
df['sales'].min()
# Out:
# np.int64(100)

# %%
df['sales'].max()
# Out:
# np.int64(300)

# %%
df['sales'].std()
# Out:
# np.float64(73.04597378168276)

# %%
df['sales'].count()
# Out:
# np.int64(8)

# %%
df['sales'].agg(['mean','min','max','median','count','std'])
# Out:
# mean      177.500000
# min       100.000000
# max       300.000000
# median    175.000000
# count       8.000000
# std        73.045974
# Name: sales, dtype: float64
