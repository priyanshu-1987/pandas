# %%
import numpy as np
import pandas as pd

# %%
data={
    'Name':['priyansu','rahul','aman','arun'],
    'Age':[20,21,22,23],
    'City':['New Delhi','Gorakhpur','Goa','Mumbai'],
    'Salary':[5400,2400,7600,8700]
}
df=pd.DataFrame(data)
df
# Out:
#        Name  Age       City  Salary
# 0  priyansu   20  New Delhi    5400
# 1     rahul   21  Gorakhpur    2400
# 2      aman   22        Goa    7600
# 3      arun   23     Mumbai    8700

# %%
#which people which age is greater than 21
df[df["Age"]>21]
# Out:
#    Name  Age    City  Salary
# 2  aman   22     Goa    7600
# 3  arun   23  Mumbai    8700

# %%
#i only want people whose age is above 21 and their city must be mumbai
df[(df["Age"]>21) & (df["City"]=='Mumbai')]
# Out:
#    Name  Age    City  Salary
# 3  arun   23  Mumbai    8700
